# %%
input = open("input_02.txt", "r")
input_list = []

for line in input:
    value = line.strip()
    value = value.split(' ')
    input_list.append(value)
        
input.close()

i=0
j=0

x=0
a=0
y=0

for i in range(0, len(input_list)):
    if input_list[i][j] == "forward":
        #print(input_list[i][j])
        #print(input_list[i][j+1])
        x = x + int(input_list[i][j+1])
        if a != 0:
            y = y + int(input_list[i][j+1])*a
    if input_list[i][j] == "down":
        a = a + int(input_list[i][j+1])
    if input_list[i][j] == "up":
        a = a - int(input_list[i][j+1])
        

print(x*y)
# Out:
# 2134882034
